# %% [markdown]
# # Линейная алгебра, математический анализ

# %% [markdown]
# ## 1 Линейная алгебра

# %% [markdown]
# 1. Даны матрицы
#
# $$
# A = \begin{pmatrix}
#     2 & -4 \\
#     3 & 5 \\
#     -1 & 0 \\
# \end{pmatrix},
# B = \begin{pmatrix}
#     1 & 2 & 7 \\
#     -3 & -4 & 0 \\
#     5 & 2 & 1 \\
# \end{pmatrix},
# C = \begin{pmatrix}
#     6 & -3 & 9 \\
#     4 & -5 & 2 \\
#     8 & 1 & 5 \\
# \end{pmatrix}
# $$
#
# Посчитайте матрицу $D = A^TC - 2A^TB^T$

# %% [markdown]
# $$
# D = A^T(C - 2B^T) = \\
# \begin{pmatrix}
#     2 & 3 & -1 \\
#     -4 & 5 & 0 \\
# \end{pmatrix}(
# \begin{pmatrix}
#     6 & -3 & 9 \\
#     4 & -5 & 2 \\
#     8 & 1 & 5 \\
# \end{pmatrix} - 2\begin{pmatrix}
#     1 & -3 & 5 \\
#     2 & -4 & 2 \\
#     7 & 0 & 1 \\
# \end{pmatrix}
# ) = \\
# \begin{pmatrix}
#     2 & 3 & -1 \\
#     -4 & 5 & 0 \\
# \end{pmatrix}(
# \begin{pmatrix}
#     6 & -3 & 9 \\
#     4 & -5 & 2 \\
#     8 & 1 & 5 \\
# \end{pmatrix} - \begin{pmatrix}
#     2 & -6 & 10 \\
#     4 & -8 & 4 \\
#     14 & 0 & 2 \\
# \end{pmatrix}
# ) = \\
# \begin{pmatrix}
#     2 & 3 & -1 \\
#     -4 & 5 & 0 \\
# \end{pmatrix}
# \begin{pmatrix}
#     4 & 3 & -1 \\
#     0 & 3 & -2 \\
#     -6 & 1 & 3 \\
# \end{pmatrix} =
# \begin{pmatrix}
#     14 & 14 & -11 \\
#     -16 & 3 & -6 \\
# \end{pmatrix}
# $$

# %% [markdown]
# 2. Дано выражение:
# $$
# 3 \cdot \begin{pmatrix}
#     x & 2 & 3 \\
#     -1 & y & 4 \\
# \end{pmatrix} + 2 \cdot \begin{pmatrix}
#     1 & 2 & -5 \\
#     2 & -6 & z \\
# \end{pmatrix} = \begin{pmatrix}
#     8 & v & -1 \\
#     1 & 6 & 4 \\
# \end{pmatrix}
# $$
#
# Найдите значения $x, y, z, v$, при которых выражение верно

# %% [markdown]
# $$
# 3x + 2 = 8 \rightarrow x = 2 \\
# 6 + 4 = v \rightarrow v = 10 \\
# 3y - 12 = 6 \rightarrow y = 6 \\
# 12 + 2z = 4 \rightarrow z = -4 \\
# $$

# %% [markdown]
# 3. Укажите те значения параметров p и q, при которых ранг матрицы $A = \begin{pmatrix}1 & 2 & 3 \\ 3 & 6 & p \\ 5 & 10 & q\end{pmatrix}$ равен единице

# %% [markdown]
# убираем вторую строку, делая коэффициенты пропорциональными первой $p = 9$
#
# убираем третью строку, делая коэффициенты пропорциональными первой $q = 15$

# %% [markdown]
# 4. Относительно канонического (стандартного) базиса в $\mathbb{R}^2$ даны три вектора $a_1 = (2, -5)^T, a_2 = (-1, 3)^T, x = (1, -4)^T$. Примите векторы $a_1, a_2$ за новый базис B, предварительно проверив, что они линейно независимы.
#
#     a. Найдите координаты вектора $x$ в новом базисе B.
#
#     b. Предположим, что координаты вектора $y$ в базисе B равны $(1, 1)^T$. Найдите координаты вектора $y$ в стандартном базисе.

# %% [markdown]
# Векторы $a_1, a_2$ линейно независимы, поскольку $\frac{2}{-1} \ne \frac{-5}{3}$

# %% [markdown]
# $$
# \begin{pmatrix}
#    2 & -1 \\
#     -5 & 3 \\
# \end{pmatrix}
# \begin{pmatrix}
#     c_1 \\
#     c_2 \\
# \end{pmatrix} =
# \begin{pmatrix}
#     1 \\
#     -4 \\
# \end{pmatrix} \\
# \begin{pmatrix}
#     c_1 \\
#     c_2 \\
# \end{pmatrix} =
# \begin{pmatrix}
#    2 & -1 \\
#     -5 & 3 \\
# \end{pmatrix}^{-1}
# \begin{pmatrix}
#     1 \\
#     -4 \\
# \end{pmatrix} \\
# \begin{pmatrix}
#     c_1 \\
#     c_2 \\
# \end{pmatrix} =
# \frac{1}{2 \cdot 3 - (-5) \cdot (-1)}
# \begin{pmatrix}
#    3 & 1 \\
#     5 & 2 \\
# \end{pmatrix}
# \begin{pmatrix}
#     1 \\
#     -4 \\
# \end{pmatrix} \\
# \begin{pmatrix}
#     c_1 \\
#     c_2 \\
# \end{pmatrix} =
# \begin{pmatrix}
#    3 & 1 \\
#     5 & 2 \\
# \end{pmatrix}
# \begin{pmatrix}
#     1 \\
#     -4 \\
# \end{pmatrix} \\
# \begin{pmatrix}
#     c_1 \\
#     c_2 \\
# \end{pmatrix} =
# \begin{pmatrix}
#     -1 \\
#     -3 \\
# \end{pmatrix} \\
# x_b = \begin{pmatrix}
#     -1 \\
#     -3 \\
# \end{pmatrix}
# $$

# %% [markdown]
# $$
# y_b = \begin{pmatrix}
#     1 \\
#     1 \\
# \end{pmatrix} \rightarrow
# y = \begin{pmatrix}
#     2 & -1 \\
#     -5 & 3 \\
# \end{pmatrix}
# \begin{pmatrix}
#     1 \\
#     1 \\
# \end{pmatrix} =
# \begin{pmatrix}
#     1 \\
#     -2 \\
# \end{pmatrix}
# $$

# %% [markdown]
# 5. Исследовательское задание: малоранговая аппроксимация матрицы. Сгенерируйте случайную квадратную матрицу $A \in \mathbb{R}^{n \times n}, n \ge 100$. С помощью функции *numpy.linalg.svd* выполните сингулярное разложение этой матрицы, и получите три матрицы: $U, S, V^T$. Выполняйте аппроксимацию матрицы $A$ с рангом $r$, меняя его значение, например от 2 до $n$:
# $$
# \widetilde{A} = U[:, :r]S[:r, :r]V^T[:r, :],
# $$
# и каждый раз считайте ошибку аппроксимации (как восстановленная матрица отличается от исходной):
# $$
# E(r) = || A - \widetilde{A} ||_F = \sqrt{\sum_{i=1}^n \sum_{j=1}^n (a_{ij} - \widetilde{a}_{ij})^2}.
# $$
# Используя библиотеку *matplotlib*, постройте график зависимости ошибки от ранга $r$.

# %%
# %pip install numpy matplotlib
# Out:
# ...
#   Using cached numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 17.8 MB/s eta 0:00:00a 0:00:01
# Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.6 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#
# [notice] A new release of pip is available: 25.0 -> 26.1
# ...

# %%
import numpy as np

n = 100
A = np.random.rand(n, n)
print(A.shape)
# Out:
# (100, 100)

# %%
U, s, Vt = np.linalg.svd(A)
S = np.diag(s)
print(f"U: {U.shape}, S: {S.shape}, Vt: {Vt.shape}")
# Out:
# U: (100, 100), S: (100, 100), Vt: (100, 100)

# %%
ranks = range(n, 1, -1)
errors = []
norm_A = np.linalg.norm(A, 'fro')

for r in ranks:
    A_approx = U[:, :r] @ S[:r, :r] @ Vt[:r, :]
    error = np.linalg.norm(A - A_approx, 'fro') / norm_A * 100
    errors.append(error)

errors = np.array(errors)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(list(ranks), errors)
plt.gca().invert_xaxis()
plt.xlabel("Ранг r")
plt.ylabel("Относительная ошибка E(r), %")
plt.title("Зависимость относительной ошибки аппроксимации от ранга")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2 Начала мат.анализа и оптимизации

# %% [markdown]
# 1. Посчитайте градиент следующей функции:
# $$
# f(x) = x^3_1 - 2x_1x_2 + x^2_2 - 3x_1 - 2x_2, x \in \mathbb{R}^2
# $$
# Найдите критические точки $x_c$, такие что $\nabla f(x_c) = 0$

# %% [markdown]
# $$
# \frac{\partial f}{\partial x_1} = 3x_1^2 - 2x_2 - 3 \\
# \frac{\partial f}{\partial x_2} = -2x_1 + 2x_2 - 2 \\
# \nabla f = \begin{bmatrix}
# \frac{\partial f}{\partial x_1} \\
# \frac{\partial f}{\partial x_2}
# \end{bmatrix} = \begin{bmatrix}
# 3x_1^2 - 2x_2 - 3 \\
# -2x_1 + 2x_2 - 2
# \end{bmatrix} \\
#
# \nabla f = 0 \implies
# \left [
# \begin{gathered}
# 3x_1^2 - 2x_2 - 3 = 0 \\
# -2x_1 + 2x_2 - 2 = 0
# \end{gathered}
# \right. \\
# x_2 = x_1 + 1 \\
# 3x_1^2 - 2(x_1 + 1) - 3 = 0 \\
# 3x_1^2 - 2x_1 - 5 = 0 \\
# \left [
# \begin{gathered}
# x_1 = -1 \\
# x_2 = 0
# \end{gathered}
# \right.
# \left [
# \begin{gathered}
# x_1 = 1\frac{2}{3} \\
# x_2 = 2\frac{2}{3}
# \end{gathered}
# \right.
# $$

# %% [markdown]
# 2. Проверьте, что функция $f = ln(\sqrt{x_1} + \sqrt{x_2})$ удовлетворяет уравнению:
# $$
# x_1\frac{\partial f}{\partial x_1} + x_2\frac{\partial f}{\partial x_2} = \frac{1}{2}
# $$

# %% [markdown]
# $$
# \frac{\partial f}{\partial x_1} = \frac{1}{\sqrt{x_1} + \sqrt{x_2}} \cdot \frac{1}{2\sqrt{x_1}} \\
# \frac{\partial f}{\partial x_2} = \frac{1}{\sqrt{x_1} + \sqrt{x_2}} \cdot \frac{1}{2\sqrt{x_2}} \\
# x_1\frac{\partial f}{\partial x_1} + x_2\frac{\partial f}{\partial x_2} = \frac{x_1}{2\sqrt{x_1}(\sqrt{x_1} + \sqrt{x_2})} + \frac{x_2}{2\sqrt{x_2}(\sqrt{x_1} + \sqrt{x_2})} = \frac{x_1\sqrt{x_2} + x_2\sqrt{x_1}}{2\sqrt{x_1x_2}(\sqrt{x_1} + \sqrt{x_2})} = \frac{x_1\sqrt{x_2} + x_2\sqrt{x_1}}{2(x_1\sqrt{x_2} + x_2\sqrt{x_1})} = \frac{1}{2}
# $$

# %% [markdown]
# 3. Предположим, задана функция $f: \mathbb{R}^3 \to \mathbb{R}^2$:
# $$
# f(x, y, z) = (x + y + z, xyz)^T
# $$
# Найдите матрицу Якоби $J_f$ функции $f$, и ее численное значение в точке $v = (1, 2, 3)^T$

# %% [markdown]
# $$
# J_f = \begin{pmatrix}
# \frac{\partial f_1}{\partial x} & \frac{\partial f_1}{\partial y} & \frac{\partial f_1}{\partial z} \\
# \frac{\partial f_2}{\partial x} & \frac{\partial f_2}{\partial y} & \frac{\partial f_2}{\partial z}
# \end{pmatrix} = \begin{pmatrix}
# 1 & 1 & 1 \\
# yz & xz & xy
# \end{pmatrix} \\
# J(1, 2, 3) = \begin{pmatrix}
# 1 & 1 & 1 \\
# 6 & 3 & 2
# \end{pmatrix}
# $$
